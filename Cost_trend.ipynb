# %% [markdown]
# <a href="https://colab.research.google.com/github/rashida048/ApacheSpark-BigDataAnalytics/blob/main/Cost_trend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
cost2 = pd.read_excel("cost_task2.xlsx", header=None)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.plot(list(range(100)), cost[0])
plt.xlabel('Iteration')
plt.ylabel("Cost")
plt.title("Cost in every iteration")
plt.show()

# %%
cost3 = pd.read_excel("cost_task3.xlsx", header=None)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.plot(list(range(200)), cost3[0])
plt.xlabel('Iteration')
plt.ylabel("Cost")
plt.title("Cost in every iteration")
plt.show()
